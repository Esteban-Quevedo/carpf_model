# %% [markdown]
# # Car Dataset Analysis Notebook

# %% [markdown]
# This notebook provides a comprehensive dataset analysis, including data loading, exploration, visualization, and preprocessing. The scatter plots are particularly useful for understanding the relationships between different variables in the dataset. The data preprocessing steps aim to filter the data based on certain conditions and remove unnecessary columns.

# %% [markdown]
# *The dataset used in this laboratory came from kaggle.com, it is an open dataset that you could download from the following __[link](https://www.kaggle.com/datasets/willstr/car-salescsv)__*

# %% [markdown]
# #### Glossary:
#
#     * Power perf factor: Performance factor that attempts to capture the overall power and performance characteristics of a vehicle

# %% [markdown]
# ### Code

# %% [markdown]
# Install all dependencies using the requirements.txt (Optional [You can install the dependencies manually, these are commented in the code])

# %%
# Uncomment the following code line to use (if required)
#!pip3 install -r requirements.txt

# %% [markdown]
# Importing Pandas Python Package

# %%
# Already contained in the requirements.txt
# Uncomment the following code line to use (if required)
# !pip3 install pandas

# %%
import pandas as pd

# %% [markdown]
# ## Data Loading and Exploration:
#
# Load the car_dataset into a dataframe

# %%
df = pd.read_csv('data/car_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv('..data/car_dataset.csv')
#
# File ~/.virtualenvs/bentoml/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# Show the Data Frame Content

# %%
df
# Out:
#     Manufacturer  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0          Acura              16.919             16.360    Passenger
# 1          Acura              39.384             19.875    Passenger
# 2          Acura              14.114             18.225    Passenger
# 3          Acura               8.588             29.725    Passenger
# 4           Audi              20.397             22.255    Passenger
# ..           ...                 ...                ...          ...
# 151        Volvo               3.545              0.000    Passenger
# 152        Volvo              15.245              0.000    Passenger
# 153        Volvo              17.531              0.000    Passenger
# 154        Volvo               3.493              0.000    Passenger
# 155        Volvo              18.969              0.000    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %% [markdown]
# Get the Data Frame Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        156 non-null    object
#  1   Sales_in_thousands  156 non-null    float64
#  2   year_resale_value   156 non-null    float64
#  3   Vehicle_type        156 non-null    object
#  4   Price_in_thousands  156 non-null    float64
#  5   Engine_size         156 non-null    float64
#  6   Horsepower          156 non-null    int64
#  7   Wheelbase           156 non-null    float64
#  8   Width               156 non-null    float64
#  9   Length              156 non-null    float64
#  10  Curb_weight         156 non-null    float64
#  11  Fuel_capacity       156 non-null    float64
#  12  Fuel_efficiency     156 non-null    int64
#  13  Power_perf_factor   156 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 17.2+ KB

# %% [markdown]
# Describe the Data Frame

# %%
df.describe()
# Out:
#        Sales_in_thousands  year_resale_value  Price_in_thousands  Engine_size  \
# count          156.000000         156.000000          156.000000   156.000000
# mean            52.994987          13.892885           27.215173     3.060897
# std             68.248508          12.642071           14.472402     1.044653
# min              0.110000           0.000000            0.000000     1.000000
# 25%             14.035000           7.668750           17.888750     2.300000
# 50%             29.213000          12.892500           22.747000     3.000000
# 75%             68.069750          17.892500           31.938750     3.575000
# max            540.561000          67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb_weight  \
# count  156.000000  156.000000  156.000000  156.000000   156.000000
# mean   185.948718  107.487179   71.150000  187.343590     3.356372
# ...

# %% [markdown]
# Importing required matplotlib required package

# %%
# Already contained in the requirements.txt
# Uncomment the following code line to use (if required)
# !pip3 install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# import matplotlib

# %% [markdown]
# Display the Data Frame Histograms

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Sales_in_thousands'}>,
#         <Axes: title={'center': 'year_resale_value'}>,
#         <Axes: title={'center': 'Price_in_thousands'}>],
#        [<Axes: title={'center': 'Engine_size'}>,
#         <Axes: title={'center': 'Horsepower'}>,
#         <Axes: title={'center': 'Wheelbase'}>],
#        [<Axes: title={'center': 'Width'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Curb_weight'}>],
#        [<Axes: title={'center': 'Fuel_capacity'}>,
#         <Axes: title={'center': 'Fuel_efficiency'}>,
#         <Axes: title={'center': 'Power_perf_factor'}>]], dtype=object)

# %% [markdown]
# Check for missing or NaN (Not a Number) values in a DataFrame

# %%
df.isna().sum()
# Out:
# Manufacturer          0
# Sales_in_thousands    0
# year_resale_value     0
# Vehicle_type          0
# Price_in_thousands    0
# Engine_size           0
# Horsepower            0
# Wheelbase             0
# Width                 0
# Length                0
# Curb_weight           0
# Fuel_capacity         0
# Fuel_efficiency       0
# Power_perf_factor     0
# dtype: int64

# %% [markdown]
# Importing matplotlib pyplot package as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Plot Engine_size (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Engine_size'], y=df['Power_perf_factor'])
plt.title('Engine_size Vs Power_perf_factor')
plt.xlabel('Engine_size')
plt.ylabel('Power_perf_factor')
plt.show()

# %% [markdown]
# Plot Fuel_efficiency (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Fuel_efficiency'], y=df['Power_perf_factor'])
plt.title('Fuel_efficiency Vs Power_perf_factor')
plt.xlabel('Fuel_efficiency')
plt.ylabel('Power_perf_factor')
plt.show()

# %% [markdown]
# Plot Price_in_thousands (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Price_in_thousands'], y=df['Power_perf_factor'])
plt.title('Price_in_thousands Vs Power_perf_factor')
plt.xlabel('Price_in_thousands')
plt.ylabel('Power_perf_factor')
plt.show()

# %% [markdown]
# Define manufacturer replacement function which convert the Manufacturer name to a number specified in a dictionary called manu_vals

# %%
def manufacturer_replacement(dtf):
    manu_vals = {"Manufacturer": {'Acura': 1, 'Audi': 2, 'BMW': 3, 'Buick': 4, 'Cadillac': 5, 'Chevrolet': 6,
                                  'Chrysler': 7, 'Dodge': 8, 'Ford': 9, 'Honda': 10, 'Hyundai': 11, 'Infiniti': 12,
                                  'Jaguar': 13, 'Jeep': 14, 'Lexus': 15, 'Lincoln': 16, 'Mitsubishi': 17, 'Mercury': 18,
                                  'Mercedes-B': 19, 'Nissan': 20, 'Oldsmobile': 21, 'Plymouth': 22, 'Pontiac': 23,
                                  'Porsche': 24, 'Saab': 25, 'Saturn': 26, 'Subaru': 27, 'Toyota': 28, 'Volkswagen': 29,
                                  'Volvo': 30}}
    dtf.replace(manu_vals, inplace=True)
    return dtf

# %% [markdown]
# Define vehicle type replacement function which convert the Vehicle Type name to a number specified in a dictionary called type_vals

# %%
def vehicle_type_replacement(dtf):
    type_vals = {"Vehicle_type": {'Car': 1, 'Passenger': 2}}
    dtf.replace(type_vals, inplace=True)
    return dtf

# %% [markdown]
# Define process data function designed to clean and filter a DataFrame according to the analysis of the previous graphs to make more consistent the data, filters like:
# * Conserve rows that contains a Price in Thousands value between 0 and 50
# * Conserve rows that contains an Engine Size value between 0 and 8
# * Conserve rows that contains a Horsepower value grater than 100
# And more...

# %%
def process_data(dtf):
    dtf = manufacturer_replacement(dtf)
    dtf = vehicle_type_replacement(dtf)
    dtf = dtf.query('Price_in_thousands>0 & Price_in_thousands<50')
    dtf = dtf.query('Engine_size>0 or Engine_size<8')
    dtf = dtf.query('Horsepower>100')
    dtf = dtf.query('Curb_weight>0.5')
    dtf = dtf.query('Fuel_efficiency>10 & Fuel_efficiency<40')
    dtf = dtf.query('Power_perf_factor>25 & Power_perf_factor<150')
    dtf = dtf.drop('Sales_in_thousands', axis=1)
    dtf = dtf.drop('year_resale_value', axis=1)
    return dtf

# %% [markdown]
# Execute the process_data function to the dataframe and save the result into the same variable "df".

# %%
df = process_data(df)

# %% [markdown]
# ## Plotting the filtered data to check the consistency of the dataset that will train the model:

# %% [markdown]
# Plot Engine_size (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Engine_size'], y=df['Power_perf_factor'])
plt.title('Engine_size Vs Power_perf_factoriency')
plt.xlabel('Engine_size')
plt.ylabel('Power_perf_factor')
plt.show()

# %% [markdown]
# Plot Fuel_efficiency (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Fuel_efficiency'], y=df['Power_perf_factor'])
plt.title('Fuel_efficiency Vs Power_perf_factor')
plt.xlabel('Fuel_efficiency')
plt.ylabel('Power_perf_factor')
plt.show()

# %% [markdown]
# Plot Price_in_thousands (X Axis) Vs Power_perf_factor (Y Axis) graph

# %%
plt.scatter(x = df['Price_in_thousands'], y=df['Power_perf_factor'])
plt.title('Price_in_thousands Vs Power_perf_factor')
plt.xlabel('Price_in_thousands')
plt.ylabel('Power_perf_factor')
plt.show()
